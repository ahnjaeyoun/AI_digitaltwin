# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset\gen_output.csv')

# %%
df.head()
# Out:
#   row_id active_mode  calculated_flow_rate_L_min  calculated_flow_rate_m3_h  \
# 0    1_0  downstroke                    18.67286                    1.12037
# 1    1_1  downstroke                    21.05727                    1.26344
# 2    1_2  downstroke                    24.37702                    1.46262
# 3    1_3  downstroke                    25.64854                    1.53891
# 4    1_4  downstroke                    27.56457                    1.65387
#
#    hydraulic_power_kW  pump_head_m  pump_delta_pressure_bar  \
# 0             5.69217   2168.69985                182.90205
# 1             6.67034   2253.60616                190.06281
# 2             7.94366   2318.31459                195.52014
# 3             8.67042   2404.97103                202.82850
# 4             9.58507   2473.86548                208.63886
#
#    load_pressure_bar_g  target_pressure_error_bar  N_PUMP_IN_p  ...  \
# 0              170.125                        0.0     -0.09244  ...
# ...

# %%
df.tail()
# Out:
#             row_id active_mode  calculated_flow_rate_L_min  \
# 1450295  100000_11    upstroke                    23.61200
# 1450296  100000_12    upstroke                    25.37328
# 1450297  100000_13    upstroke                    28.10257
# 1450298  100000_14    upstroke                    31.58472
# 1450299  100000_15    upstroke                    32.52519
#
#          calculated_flow_rate_m3_h  hydraulic_power_kW  pump_head_m  \
# 1450295                    1.41672             5.84960   1762.48385
# 1450296                    1.52240             6.47134   1814.47088
# 1450297                    1.68615             7.28382   1843.93405
# 1450298                    1.89508             8.46420   1906.51863
# 1450299                    1.95151             8.99805   1968.16033
#
#          pump_delta_pressure_bar  load_pressure_bar_g  \
# 1450295                148.64294              131.678
# 1450296                153.02738              135.029
# ...

# %%
df.describe()
# Out:
#        calculated_flow_rate_L_min  calculated_flow_rate_m3_h  \
# count                1.450300e+06               1.450300e+06
# mean                 2.343347e+01               1.406008e+00
# std                  1.008659e+01               6.051954e-01
# min                  0.000000e+00               0.000000e+00
# 25%                  2.001618e+01               1.200970e+00
# 50%                  2.515398e+01               1.509240e+00
# 75%                  3.013032e+01               1.807820e+00
# max                  5.216317e+01               3.129790e+00
#
#        hydraulic_power_kW   pump_head_m  pump_delta_pressure_bar  \
# count        1.450300e+06  1.450300e+06             1.450300e+06
# mean         7.091944e+00  1.921308e+03             1.620377e+02
# std          3.337816e+00  7.247384e+02             6.112240e+01
# min          0.000000e+00  0.000000e+00             0.000000e+00
# 25%          5.479460e+00  1.767604e+03             1.490747e+02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450300 entries, 0 to 1450299
# Data columns (total 38 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   row_id                      1450300 non-null  object
#  1   active_mode                 1450300 non-null  object
#  2   calculated_flow_rate_L_min  1450300 non-null  float64
#  3   calculated_flow_rate_m3_h   1450300 non-null  float64
#  4   hydraulic_power_kW          1450300 non-null  float64
#  5   pump_head_m                 1450300 non-null  float64
#  6   pump_delta_pressure_bar     1450300 non-null  float64
#  7   load_pressure_bar_g         1450300 non-null  float64
#  8   target_pressure_error_bar   1450300 non-null  float64
#  9   N_PUMP_IN_p                 1450300 non-null  float64
#  10  N_PUMP_OUT_p                1450300 non-null  float64
#  11  N_VALVE_P_p                 1450300 non-null  float64
# ...

# %%
df
# Out:
#             row_id active_mode  calculated_flow_rate_L_min  \
# 0              1_0  downstroke                    18.67286
# 1              1_1  downstroke                    21.05727
# 2              1_2  downstroke                    24.37702
# 3              1_3  downstroke                    25.64854
# 4              1_4  downstroke                    27.56457
# ...            ...         ...                         ...
# 1450295  100000_11    upstroke                    23.61200
# 1450296  100000_12    upstroke                    25.37328
# 1450297  100000_13    upstroke                    28.10257
# 1450298  100000_14    upstroke                    31.58472
# 1450299  100000_15    upstroke                    32.52519
#
#          calculated_flow_rate_m3_h  hydraulic_power_kW  pump_head_m  \
# 0                          1.12037             5.69217   2168.69985
# 1                          1.26344             6.67034   2253.60616
# ...

# %%
df2 = pd.read_csv('dataset/final_training_dataset.csv')
df2
# Out:
# C:\Users\vnm19\AppData\Local\Temp\ipykernel_23920\1170970244.py:1: DtypeWarning: Columns (38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('dataset/final_training_dataset.csv')
#          cycle_id  cycle_second cycle_phase target_chamber  temperature_c  \
# 0               1             0  downstroke            cap         43.714
# 1               1             1  downstroke            cap         43.724
# 2               1             2  downstroke            cap         43.743
# 3               1             3  downstroke            cap         43.660
# 4               1             4  downstroke            cap         43.693
# ...           ...           ...         ...            ...            ...
# 1450295    100000            11    upstroke            rod         76.602
# 1450296    100000            12    upstroke            rod         76.638
# 1450297    100000            13    upstroke            rod         76.720
# ...

# %%
print(df2.columns[38])
print(df2.columns[39])

print(df2.iloc[:, 38].value_counts(dropna=False).head(20))
print(df2.iloc[:, 39].value_counts(dropna=False).head(20))
# Out:
# gt_leak_mode
# gt_fault_location
# gt_leak_mode
# NaN               1145944
# internal           101527
# external           101454
# valve_internal     101375
# Name: count, dtype: int64
# gt_fault_location
# NaN              435352
# V_RELIEF         203092
# V_DIR_PA         118888
# C_SUCTION        101575
# PUMP_01          101552
# N_CYL_CAP-ROD    101527
# Fluid            101449
# C_PRESSURE       101394
# V_DIR_PB          84017
# N_VALVE_A         34589
# N_VALVE_P         33529
# N_CYL_CAP         33336
# Name: count, dtype: int64
